# %% [markdown]
# # Environment Setup
# Load packages & define parameters

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.set_option('display.max_columns', None) #increase column width to unlimited
pd.set_option('display.max_rows', 50)
# !pip install yfinance
import yfinance as yf
from datetime import datetime


apikey = ''
url = "https://www.alphavantage.co/query"
stock = 'TSLA'

# %% [markdown]
# # Company Financial information
# Summary figures from most recent filing

# %%
# Company Financial information 
# source: https://www.alphavantage.co/documentation/
# alternate source: Scrape FinViz - https://towardsdatascience.com/get-up-to-date-financial-ratios-p-e-p-b-and-more-of-stocks-using-python-4b53dd82908f

querystring = {"function":"OVERVIEW","symbol":stock,"apikey":apikey}
response = requests.request("GET", url, params=querystring)
# print(response.text)
response_tbl = pd.json_normalize(response.json())
(response_tbl)

#ALTERNATIVE CODE
# response = requests.get('https://www.alphavantage.co/query',
#     params={"function":"OVERVIEW","symbol":"TSLA","apikey":apikey}
# #     headers={'Authorization': '', 'Accept': 'application/json'}
# )
# print(response)
# json_response = response.json()
# print(response.status_code)
# print(json_response)
# Out:
#   Symbol     AssetType        Name  \
# 0   TSLA  Common Stock  Tesla, Inc
#
#                                          Description Exchange Currency  \
# 0  Tesla, Inc. designs, develops, manufactures, l...   NASDAQ      USD
#
#   Country             Sector            Industry  \
# 0     USA  Consumer Cyclical  Auto Manufacturers
#
#                                              Address FullTimeEmployees  \
# 0  3500 Deer Creek Road, Palo Alto, CA, United St...             70757
#
#   FiscalYearEnd LatestQuarter MarketCapitalization      EBITDA    PERatio  \
# 0      December    2020-12-31         783356067840  4272999936  1275.1875
#
#   PEGRatio BookValue DividendPerShare DividendYield   EPS RevenuePerShareTTM  \
# 0   1.6084    23.151             None             0  0.64             33.801
#
#   ProfitMargin OperatingMarginTTM ReturnOnAssetsTTM ReturnOnEquityTTM  \
# 0       0.0229             0.0619            0.0282            0.0542
#
#     RevenueTTM GrossProfitTTM DilutedEPSTTM QuarterlyEarningsGrowthYOY  \
# 0  31536001024     6630000000          0.64                      1.055
#
#   QuarterlyRevenueGrowthYOY AnalystTargetPrice TrailingPE ForwardPE  \
# 0                     0.455             610.34  1275.1875       200
#
#   PriceToSalesRatioTTM PriceToBookRatio EVToRevenue EVToEBITDA    Beta  \
# 0               28.027          35.2466     24.6465   184.0082  2.0907
#
#   52WeekHigh 52WeekLow 50DayMovingAverage 200DayMovingAverage  \
# 0      895.9    70.102           814.9055            536.6286
#
#   SharesOutstanding SharesFloat SharesShort SharesShortPriorMonth ShortRatio  \
# 0         959854016   769140211    52379526              56367815        1.4
#
#   ShortPercentOutstanding ShortPercentFloat PercentInsiders  \
# 0                    0.05            0.0679          19.985
#
#   PercentInstitutions ForwardAnnualDividendRate ForwardAnnualDividendYield  \
# 0              42.529                         0                          0
#
#   PayoutRatio DividendDate ExDividendDate LastSplitFactor LastSplitDate
# 0           0         None           None             5:1    2020-08-31

# %% [markdown]
# #  Balance Sheet
# Includes Annual & Quarterly financial filings

# %%
# Balance Sheet - This API returns the annual and quarterly balance sheets 
# for the company of interest. Data is generally refreshed on the same day a
# company reports its latest earnings and financials.

querystring = {"function":"BALANCE_SHEET",
               "symbol":stock,"apikey":apikey}
response = requests.request("GET", url, params=querystring)
Balance_Sheet_ann= response.json()['annualReports']
Balance_Sheet_ann = pd.json_normalize(Balance_Sheet_ann)
Balance_Sheet_ann.insert(0,'Stock',stock)
# Balance_Sheet_ann['Stock'] = stock #alternative

Balance_Sheet_qtr = response.json()['quarterlyReports']
Balance_Sheet_qtr = pd.json_normalize(Balance_Sheet_qtr)
Balance_Sheet_qtr.insert(0,'Stock',stock)
# Balance_Sheet_qtr['Stock'] = stock #alternative

# Balance_Sheet_total = [annual,quarterly]
# Balance_Sheet = pd.concat(Balance_Sheet)
# Out:
#    Stock fiscalDateEnding reportedCurrency totalAssets intangibleAssets  \
# 0    FLR       2020-09-30              USD  7271650000             None
# 1    FLR       2020-06-30              USD  7240774000             None
# 2    FLR       2020-03-31              USD  7292469000             None
# 3    FLR       2019-12-31              USD  7966658000             None
# 4    FLR       2019-09-30              USD  7883707000         32000000
# 5    FLR       2019-06-30              USD  8973874000             None
# 6    FLR       2019-03-31              USD  9041714000             None
# 7    FLR       2018-12-31              USD  8913637000             None
# 8    FLR       2018-09-30              USD  9147976000        553294000
# 9    FLR       2018-06-30              USD  9119217000        558308000
# 10   FLR       2018-03-31              USD  9425226000        581298000
# 11   FLR       2017-12-31              USD  9327692000        753035000
# 12   FLR       2017-09-30              USD  9193527000        563440000
# 13   FLR       2017-06-30              USD  9221808000        548849000
# 14   FLR       2017-03-31              USD  9160335000        545400000
# 15   FLR       2016-12-31              USD  9216417000        722536000
# 16   FLR       2016-09-30              USD  9316606000        593161000
# 17   FLR       2016-06-30              USD  9241467000        567264000
# 18   FLR       2016-03-31              USD  9001727000                0
# 19   FLR       2015-12-31              USD  7631506000        111646000
# 20   FLR       2015-09-30              USD  7599361000                0
#
#    earningAssets otherCurrentAssets totalLiabilities totalShareholderEquity  \
# 0           None         1815752000       5292138000             1128946000
# 1           None         1898321000       5334697000             1091722000
# 2           None         2154338000       5437139000             1091645000
# 3           None         1554527000       6478906000             1487752000
# 4           None         2424162000       5487276000             1559495000
# 5           None         1736401000       5714942000             2374237000
# 6           None         1957623000       5178820000             2952313000
# 7           None         1926980000       5214078000             2963181000
# 8           None         1937226000       5948047000             3043024000
# 9           None         2116249000       5327017000             3043355000
# 10          None         2138831000       5685959000             2996311000
# 11          None          574764000       5165768000             3342310000
# 12          None          650059000       5124548000             3283308000
# 13          None          689991000       5293742000             3177686000
# 14          None          482117000       5202392000             3220835000
# 15          None          411284000       5333978000             3125191000
# 16          None          536255000       5431719000             3106285000
# 17          None          426390000       5327489000             3139548000
# 18          None          435216000       5780893000             3088611000
# 19          None          378927000       4518007000             2997347000
# 20          None          305790000       4423419000             3062340000
#
#    deferredLongTermLiabilities otherCurrentLiabilities commonStock  \
# 0                     70363000              1099926000     1403000
# 1                     74787000              1077663000     1403000
# 2                     79420000              1203358000     1403000
# 3                     83295000              1543560000     1399000
# 4                         None              1510233000     1399000
# 5                         None              1434529000     1399000
# 6                         None               868950000     1399000
# 7                         None               855948000     1396000
# 8                            0               892860000     1407000
# 9                            0               961940000     1406000
# 10                           0              1193465000     1406000
# 11                           0              2034069000     1399000
# 12                           0              2108667000     1399000
# 13                           0              2169060000     1399000
#    otherNonCurrrentAssets deferredLongTermAssetCharges totalNonCurrentAssets  \
# 0               489600000                         None            2261251000
# 1               416399000                         None             377480000
# 2               485004000                         None            2162980000
# 3               478616000                         None            2450386000
# 4               494145000                         None             429841000
# 5               622922000                         None             870033000
# 6               622012000                         None             718833000
# 7               315997000                         None             670940000
# 8               335090000                         None             787053000
# 9               369835000                         None             776322000
# 10              371135000                         None             781474000
# 11              377288000                         None             698298000
# 12              377213000                         None             680119000
# 13              372623000                         None             708356000
# 14              381260000                         None             724550000
# 15              370151000                         None             802596000
# 16              382774000                         None             660640000
# 17              383253000                    339206000             332432000
# 18              209096000                    362699000             326444000
# 19              207999000                    221945000             360725000
# 20              214392000                    220855000             349103000
#
#    capitalLeaseObligations totalLongTermDebt otherNonCurrentLiabilities  \
# 0                     None        1677162000                  672828000
# 1                     None        1654831000                  675183000
# 2                     None        1647173000                  645165000
# 3                     None        1651739000                  715471000
# 4                     None        1636905000                  712501000
# 5                     None        1657246000                  761443000
# 6                     None        1650927000                  746969000
# 7                     None        1661565000                       None
# 8                     None        1667359000                  618585000
# 9                     None        1575370000                       None
# 10                    None        1607653000                       None
# 11                    None        1591598000                       None
# 12                    None        1580974000                       None
# 13                    None        1560471000                       None
# 14                    None        1526023000                       None
# 15                    None        1517949000                       None
# 16                    None        1555522000                       None
# 17                    None        1547459000                       None
# 18                    None        1572001000                  618962000
# 19                    None         992664000                  589991000
# 20                    None         992689000                  568929000
#
#    totalNonCurrentLiabilities negativeGoodwill warrants  \
# 0                  1747525000             None     None
# 1                  1729618000             None     None
# 2                  1726593000             None     None
# 3                  2450505000             None     None
# 4                  1636905000             None     None
# 5                  1657246000             None     None
# 6                  1650927000             None     None
# 7                  1661565000             None     None
# 8                  2285944000             None     None
# 9                  1575370000             None     None
# 10                 1607653000             None     None
# 11                 1591598000             None     None
# 12                 1580974000             None     None
# 13                 1560471000             None     None
# 14                 1526023000             None     None
# 15                 1517949000             None     None
# 16                 1555522000             None     None
# 17                 1547459000             None     None
# 18                 2190963000             None     None
# 19                 1582655000             None     None
# 20                 1561618000             None     None
#
#    preferredStockRedeemable capitalSurplus liabilitiesAndShareholderEquity  \
# 0                      None      177617000                      7271650000
# 1                      None      175089000                      7240774000
# 2                      None      170750000                      7292469000
# 3                      None      165314000                      7966658000
# 4                      None      111857000                      7883707000
# 5                      None      113042000                      8973874000
# 6                      None       94456000                      9041714000
# 7                      None       82106000                      8913637000
# 8                      None      122267000                      9147976000
# 9                      None      111368000                      9119217000
# 10                     None       99028000                      9425226000
# 11                     None       88222000                      9327692000
# 12                     None       77449000                      9193527000
# 13                     None       67905000                      9221808000
# 14                     None       58371000                      9160335000
# 15                     None       38317000                      9216417000
# 16                     None       29985000                      9316606000
# 17                     None       21441000                      9241467000
# 18                     None       10819000                      9001727000
# 19                     None           None                      7631506000
# 20                     None           None                      7599361000
#
#    cashAndShortTermInvestments accumulatedDepreciation  \
# 0                   2111296000                    None
# 1                   1982304000                    None
# 2                   1877351000                    None
# 3                   2004461000                    None
# 4                   1852977000                    None
# 5                   1930383000                    None
# 6                   1904510000                    None
# 7                   1979574000             -1220802000
# 8                   1922844000                    None
# 9                   1783084000                    None
# 10                  1828457000                    None
# 11                  1965209000             -1201929000
# 12                  2005085000                    None
# 13                  2013726000                    None
# 14                  2042523000                    None
# 15                  1961473000             -1122191000
# 16                  1911195000                    None
# 17                  1752140000                    None
# 18                  1864621000                    None
# 19                  2146978000             -1046077000
# 20                  2027151000                    None
#
#    commonStockSharesOutstanding
# 0                     140609216
# 1                     140565020
# 2                     140533363
# 3                     140174400
# 4                     140174400
# 5                     140174400
# 6                     140108765
# 7                     139653824
# 8                     140749228
# 9                     140699850
# 10                    140597739
# 11                    139918324
# 12                    139902454
# 13                    139876865
# 14                    139781114
# 15                    139258483
# 16                    139250204
# 17                    139243680
# 18                    139222687
# 19                    139018309
# 20                    142219163

# %% [markdown]
# # Income Statement
# Includes Annual & Quarterly financial filings

# %%
# Income Statement - This API returns the annual and quarterly income 
# statements for the company of interest. Data is generally refreshed on 
# the same day a company reports its latest earnings and financials.

querystring = {"function":"INCOME_STATEMENT",
               "symbol":stock,"apikey":apikey}
response = requests.request("GET", url, params=querystring)
Income_Statement_ann = response.json()['annualReports']
Income_Statement_ann = pd.json_normalize(Income_Statement_ann)
Income_Statement_ann.insert(0,'Stock',stock)

Income_Statement_qtr = response.json()['quarterlyReports']
Income_Statement_qtr = pd.json_normalize(Income_Statement_qtr)
Income_Statement_qtr.insert(0,'Stock',stock)
Income_Statement_qtr

# %%
#stock price on Qtr End Date
common_stock_qtr = int(Balance_Sheet_qtr['commonStock'][0])
date = (Income_Statement_qtr['fiscalDateEnding'][0])
date=date+' 11:00'
datetime_object = datetime.strptime(date, '%Y-%m-%d %H:%M')
stock_price_qtr=yf.download(stock, start=datetime_object, end=datetime_object)['Adj Close'][0]

#stock price on Ann End Date
common_stock_ann = int(Balance_Sheet_ann['commonStock'][0])
date = (Income_Statement_ann['fiscalDateEnding'][0])
date=date+' 11:00'
datetime_object = datetime.strptime(date, '%Y-%m-%d %H:%M')
stock_price_ann=yf.download(stock, start=datetime_object, end=datetime_object)['Adj Close'][0]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Key Ratios

# %%
# Quarterly
workcap_qtr = (int(Balance_Sheet_qtr['totalCurrentAssets'][0])-int(Balance_Sheet_qtr['totalCurrentLiabilities'][0]))/1000000
total_assets_qtr = int(Balance_Sheet_qtr['totalAssets'][0])
retained_earnings_qtr = int(Balance_Sheet_qtr['retainedEarnings'][0])
total_liabilities_qtr = int(Balance_Sheet_qtr['totalLiabilities'][0])
mkt_capt_qtr = common_stock_qtr*stock_price_qtr
sales_qtr = int(Income_Statement_qtr['totalRevenue'][0])                         
EBIT_qtr = int(Income_Statement_qtr['ebit'][0])

# %%
# Annual
workcap_ann = (int(Balance_Sheet_ann['totalCurrentAssets'][0])-int(Balance_Sheet_ann['totalCurrentLiabilities'][0]))/1000000
total_assets_ann = int(Balance_Sheet_ann['totalAssets'][0])
retained_earnings_ann = int(Balance_Sheet_ann['retainedEarnings'][0])
total_liabilities_ann = int(Balance_Sheet_ann['totalLiabilities'][0])
mkt_capt_ann = common_stock_ann*stock_price_ann
sales_ann = int(Income_Statement_ann['totalRevenue'][0])                         
EBIT_ann = int(Income_Statement_ann['ebit'][0])

# %% [markdown]
# # Altman Z Score
# Assumption: This formula is basically designed for publicly held manufacturing firms with values of more than $1 million of net worth.

# %%
# Altman’s Z-Score: A numerical measurement used to predict the chances of a business going bankrupt in the next two years
# source: https://corporatefinanceinstitute.com/resources/knowledge/credit/altmans-z-score-model/
# The Z-score model is based on five key financial ratios, and it relies on the information contained in the 10-K report. 
# It increases the model’s accuracy when measuring the financial health of a company and its probability of going bankrupt.

# ζ = 1.2A + 1.4B + 3.3C + 0.6D + 1.0E 
# Where: Zeta (ζ) is the Altman’s Z-score 
#     A is the Working Capital/Total Assets ratio - Firm Liquidity
#     B is the Retained Earnings/Total Assets ratio - Profits compared to Assets
#     C is the Earnings Before Interest and Tax/Total Assets ratio - Profits generated by Assets
#     D is the Market Value of Equity/Total Liabilities ratio - Value versus Liabilities
#     E is the Total Sales/Total Assets ratio - Asset Efficiency Ratio

# Financial Distress - Zscore < 1.8; 
# Moderate Bankruptcy Risk - 1.8 < Zscore < 3; 
# Safe Zone - Zscore > 3
A = workcap_qtr / total_assets_qtr
B = retained_earnings_qtr / total_assets_qtr
C = EBIT_qtr / total_assets_qtr
D = mkt_capt_qtr / total_liabilities_qtr
E = sales_qtr / total_assets_qtr

Z = 1.2*A + 1.4*B + 3.3*C + 0.6*D + 1.0*E
Z
# Out:
# 0.8383536132253651

# %%
print("A = {:.3n} B = {} C = {:.3n} D = {:.3n} E = {:.3n}".format(A,B,C,D,E))
# Out:
# A = 2.02e-07 B = 0.19434956302902368 C = 0.0127 D = 0.00234 E = 0.523

# %% [markdown]
# # Altman Z Score
# Assumption: This formula is modified for the case of private firms

# %%
# Altman’s Z-Score: A numerical measurement used to predict the chances of a business going bankrupt in the next two years
# source: https://corporatefinanceinstitute.com/resources/knowledge/credit/altmans-z-score-model/
# The Z-score model is based on five key financial ratios, and it relies on the information contained in the 10-K report. 
# It increases the model’s accuracy when measuring the financial health of a company and its probability of going bankrupt.

# ζ = 0.717A + 0.847B + 3.107C + 0.420D + 0.998E 
# Where: Zeta (ζ) is the Altman’s Z-score 
#     A is the Working Capital/Total Assets ratio 
#     B is the Retained Earnings/Total Assets ratio 
#     C is the Earnings Before Interest and Tax/Total Assets ratio 
#     D is the Book Value of Equity/Total Liabilities ratio 
#     E is the Total Sales/Total Assets ratio

# Financial Distress - Zscore < 1.23; 
# Moderate Bankruptcy Risk - 1.23 < Zscore < 3; 
# Safe Zone - Zscore > 3
A = workcap_qtr / total_assets_qtr
B = retained_earnings_qtr / total_assets_qtr
C = EBIT_qtr / total_assets_qtr
D = mkt_capt_qtr / total_liabilities_qtr
E = sales_qtr / total_assets_qtr

Z = 0.717*A + 0.847*B + 3.107*C + 0.42*D + 0.998*E
Z
# Out:
# 0.7269645318236548

# %% [markdown]
# # Altman Z Score
# Assumption: This formula is modified for the case of non-manufacturing firms operating in emerging and developed markets.

# %%
# Altman’s Z-Score: A numerical measurement used to predict the chances of a business going bankrupt in the next two years
# source: https://corporatefinanceinstitute.com/resources/knowledge/credit/altmans-z-score-model/
# The Z-score model is based on five key financial ratios, and it relies on the information contained in the 10-K report. 
# It increases the model’s accuracy when measuring the financial health of a company and its probability of going bankrupt.

# Formula
# Non-manufacturing firm, operating in developed markets
# ζ = 6.56A + 3.26B + 6.72C + 1.05D 
# Non-manufacturing firm operating in emerging markets
# ζ = 3.25 + 6.56A + 3.26B + 6.72C + 1.05D 

# Where: Zeta (ζ) is the Altman’s Z-score 
#     A is the Working Capital/Total Assets ratio 
#     B is the Retained Earnings/Total Assets ratio 
#     C is the Earnings Before Interest and Tax/Total Assets ratio 
#     D is the Book Value of Equity/Total Liabilities ratio 

# Financial Distress - Zscore < 1.1; 
# Moderate Bankruptcy Risk - 1.1 < Zscore < 2.6; 
# Safe Zone - Zscore > 2.6
A = workcap_qtr / total_assets_qtr
B = retained_earnings_qtr / total_assets_qtr
C = EBIT_qtr / total_assets_qtr
D = mkt_capt_qtr / total_liabilities_qtr
E = sales_qtr / total_assets_qtr

Z = 6.65*A + 3.26*B + 6.72*C + 1.05*D
Z
# Out:
# 0.7212424359869074

# %% [markdown]
# # Cash Flow Statement
# Includes Annual & Quarterly financial filings

# %%
# Cash Flow - This API returns the annual and quarterly cash flows 
# for the company of interest. Data is generally refreshed on the same day a 
# company reports its latest earnings and financials.

querystring = {"function":"CASH_FLOW",
               "symbol":stock,"apikey":apikey}
response = requests.request("GET", url, params=querystring)
Cashflow_ann = response.json()['annualReports']
Cashflow_ann = pd.json_normalize(Cashflow_ann)
Cashflow_ann.insert(0,'Stock',stock)

Cashflow_qtr = response.json()['quarterlyReports']
Cashflow_qtr = pd.json_normalize(Cashflow_qtr)
Cashflow_qtr.insert(0,'Stock',stock)
# Out:
#   Stock fiscalDateEnding reportedCurrency investments changeInLiabilities  \
# 0  SPCE       2020-09-30              USD    -3996000             3089000
# 1  SPCE       2020-06-30              USD    -6103000              534000
# 2  SPCE       2020-03-31              USD    -4036000            -3076000
# 3  SPCE       2019-12-31              USD   -58507085            -1723000
# 4  SPCE       2019-09-30              USD        None             6486000
# 5  SPCE       2019-06-30              USD        None            -1706000
# 6  SPCE       2019-03-31              USD        None             -901000
# 7  SPCE       2018-12-31              USD        None                None
#
#   cashflowFromInvestment otherCashflowFromInvestment netBorrowings  \
# 0               -3996000                        None        -40000
# 1               -6103000                        None        -26000
# 2               -4036000                        None        -23000
# 3               -5731000                        None        -49000
# 4               -5380000                    39096090         -8000
# 5               -5232000                        None        -24000
# 6               -3068000                        None        -23000
# 7                   None                        None          None
#
#   cashflowFromFinancing otherCashflowFromFinancing  \
# 0             440362000                  -19399000
# 1               -796000                    -770000
# 2               -720000                    -697000
# 3             672071947                  -48005000
# 4             -38129686                  -48005000
# 5                354290                  -48005000
# 6                 23450                      23450
# 7                912440                     255300
#
#   changeInOperatingActivities   netIncome changeInCash operatingCashflow  \
# 0                     4393000   -76950000    381665000         -54701000
# 1                     2011000   -62518000    -58474000         -51575000
# 2                     2142000   -59930000    -61069000         -56313000
# 3                    -4912000  -215940004    411766673         -75270000
# 4                     2392000     -482184      -225806          -1192205
# 5                     1524000     1444193       -52051           -406341
# 6                     -568000     4043000      -135820           -159270
# 7                        None    10965010      -234220          -1146660
#
#   otherOperatingCashflow depreciation dividendPayout stockSaleAndPurchase  \
# 0                   None      2677000           None                 None
# 1                   None      2615000           None                 None
# 2                   None      2105000           None                 None
# 3                   None      6999000           None             20000000
# 4                   None         None           None            -39096090
# 5                   None         None           None                 None
# 6                   None         None           None                 None
# 7                   None         None           None               657140
#
#   changeInInventory changeInAccountReceivables changeInNetIncome  \
# 0           3457000                       None           8633000
# 1            192000                       None           5591000
# 2          -1980000                       None           4426000
# 3          -1218000                     431000           2872000
# 4              None                       None           -129000
# 5              None                       None           -129000
# 6              None                       None           -117000
# 7              None                       None              None
#
#   capitalExpenditures changeInReceivables changeInExchangeRate  \
# 0             3996000                None                 None
# 1             6103000                None                 None
# 2             4036000                None                 None
# 3            19411000                None                 None
# 4                   0                None                 None
# 5                   0                None                 None
# 6                   0                None                 None
# 7                   0                None                 None
#
#   changeInCashAndCashEquivalents
# 0                           None
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# 5                           None
# 6                           None
# 7                           None

# %%
# Earnings - This API returns the annual and quarterly earnings (EPS) 
# for the company of interest. Quarterly data also includes analyst 
# estimates and surprise metrics.

querystring = {"function":"EARNINGS",
               "symbol":stock,"apikey":apikey}
response = requests.request("GET", url, params=querystring)
Earnings_ann = response.json()['annualEarnings']
Earnings_ann = pd.json_normalize(Earnings_ann)
Earnings_ann.insert(0,'Stock',stock)

Earnings_qtr = response.json()['quarterlyEarnings']
Earnings_qtr = pd.json_normalize(Earnings_qtr)
Earnings_qtr.insert(0,'Stock',stock)
Earnings_qtr
# Out:
#    Stock fiscalDateEnding reportedDate reportedEPS estimatedEPS surprise  \
# 0   SPCE       2020-09-30   2020-11-05       -0.34      -0.2756  -0.0644
# 1   SPCE       2020-06-30   2020-08-03        -0.3       -0.264   -0.036
# 2   SPCE       2020-03-31   2020-05-05        -0.3        -0.18    -0.12
# 3   SPCE       2019-12-31   2020-02-25      -0.302       -0.208   -0.094
# 4   SPCE       2019-09-30   2019-11-07     -0.0059         None     None
# 5   SPCE       2019-06-30   2019-08-06      0.0168         None     None
# 6   SPCE       2019-03-31   2019-05-08      0.0469         None     None
# 7   SPCE       2018-12-31   2019-03-18      0.0432         None     None
# 8   SPCE       2018-09-30   2018-09-30      0.0352         None     None
# 9   SPCE       2018-06-30   2018-06-30      0.0613         None     None
# 10  SPCE       2018-03-31   2018-03-31      0.0451         None     None
# 11  SPCE       2017-12-31   2017-12-31      0.0356         None     None
# 12  SPCE       2017-09-30   2017-09-30      0.0017         None     None
#
#    surprisePercentage
# 0            -23.3672
# 1            -13.6364
# 2            -66.6667
# 3            -45.1923
# 4                None
# 5                None
# 6                None
# 7                None
# 8                None
# 9                None
# 10               None
# 11               None
# 12               None

# %%
# Listing & Delisting Status - This API returns a list of active or delisted
# US stocks and ETFs, either as of the latest trading day or at a specific 
# time in history. The endpoint is positioned to facilitate equity research
# on asset lifecycle and survivorship.
from io import StringIO

#delisted stocks as of the latest trading day
querystring = {"function":"LISTING_STATUS","state":"delisted","apikey":apikey}
response = requests.request("GET", url, params=querystring)
delisted=pd.read_csv(StringIO(response.text))

#active stocks as of the latest trading day
querystring = {"function":"LISTING_STATUS","state":"active","apikey":apikey}
response = requests.request("GET", url, params=querystring)
active=pd.read_csv(StringIO(response.text))
